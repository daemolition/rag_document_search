# %%
from pypdf import PdfReader


# Load the PDF file
pdf = PdfReader("data/icd/icd10gm2026syst_referenz_20250912.pdf")

meta = pdf.metadata

# %%
page = pdf.pages[600].extract_text()
page
# Out:
# '  S13.-  Luxation, Verstauchung und Zerrung von Gelenken und Bändern in \nHalshöhe\nBenutze eine zusätzliche Schlüsselnummer aus S11.84!-S11.89! zusammen mit S13.0-S13.3, um \nden Schweregrad des Weichteilschadens bei einer Luxation zu verschlüsseln.\nEine Verletzung des zervikalen Rückenmarks ist zusätzlich mit S14.- zu verschlüsseln.\nDas Vorliegen von Halswirbelfrakturen bei einer Luxation ist zusätzlich mit S12.- zu verschlüsseln. \nIst die Zahl der zusammen mit der Luxation gebrochenen Halswirbel nicht bekannt, so ist die \nFraktur auf der höchsten Ebene zu verschlüsseln.\nExkl.: Ruptur oder Verlagerung (nichttraumatisch) einer zervikalen Bandscheibe (M50.-)\nVerstauchung und Zerrung von Muskeln und Sehnen in Halshöhe (S16)\nS13.0 Traumatische Ruptur einer zervikalen Bandscheibe\nS13.1- Luxation eines Halswirbels\nS13.10 Höhe nicht näher bezeichnet\nS13.11 C1/C2\nS13.12 C2/C3\nS13.13 C3/C4\nS13.14 C4/C5\nS13.15 C5/C6\nS13.16 C6/C7\nS13.17 C7/T1\nS13.18 Sonstige\nS13.2 Luxation sonstiger und nicht näher bezeichneter Teile im Bereich des Halses\nS13.3 Multiple Luxationen im Bereich des Halses\nS13.4 Verstauchung und Zerrung der Halswirbelsäule\nAtlantoaxial (-Gelenk)\nAtlantookzipital (-Gelenk)\nLig. longitudinale anterius, zervikal\nSchleudertrauma der Halswirbelsäule\nS13.5 Verstauchung und Zerrung in der Schilddrüsenregion\nKrikoarytänoidal (-Gelenk) (-Band)\nKrikothyreoidal (-Gelenk) (-Band)\nSchildknorpel\nS13.6 Verstauchung und Zerrung von Gelenken und Bändern sonstiger und nicht näher \nbezeichneter Teile des Halses\n  S14.-  Verletzung der Nerven und des Rückenmarkes in Halshöhe\nBenutze zusätzlich die Schlüsselnummer S19.80, um eine Verletzung zervikaler Rückenmarkhäute \nanzugeben.\nS14.0 Kontusion und Ödem des zervikalen Rückenmarkes\nS14.1- Sonstige und nicht näher bezeichnete Verletzungen des zervikalen Rückenmarkes\nVerschlüssele auch die funktionale Höhe einer Verletzung des zervikalen Rückenmarks (S14.7-!)\nS14.10 Verletzungen des zervikalen Rückenmarkes, nicht näher bezeichnet\nS14.11 Komplette Querschnittverletzung des zervikalen Rückenmarkes\nS14.12 Zentrale Halsmarkverletzung (inkomplette Querschnittverletzung)\nS14.13 Sonstige inkomplette Querschnittverletzungen des zervikalen Rückenmarkes\nS14.2 Verletzung von Nervenwurzeln der Halswirbelsäule\nS14.3 Verletzung des Plexus brachialis\nS14.4 Verletzung peripherer Nerven des Halses\nS14.5 Verletzung zervikaler sympathischer Nerven\nS14.6 Verletzung sonstiger und nicht näher bezeichneter Nerven des Halses\nICD-10-GM Version 2026\n601'

# %%
import re

chunks = []

for page in pdf.pages:
    pattern = r'([A-Z][0-9][0-9](?:\.[0-9A-Z]+)?)'

    extract = page.extract_text()
    codes = re.findall(pattern, extract)

    for i, code in enumerate(codes):
        start = extract.find(code)
        end = extract.find(codes[i+1], start) if i+1 < len(codes) else len(extract)
        section = extract[start:end].strip()
        chunks.append({"code": code, "text": section, "page_number": pdf.pages.index(page)+1})

# %%
metadata = {
 'Author': meta.get('/Author', ''),
 'CreationDate': meta.get('/CreationDate', ''),
 'Creator': meta.get('/Creator', ''),
 'ModDate': meta.get('/ModDate', ''),
 'Title': meta.get('/Title', ''),
}

# %%
for code in chunks:
    metadata.update({'ICD_Code': code['code'], 'Page_Number': code['page_number']})

# %%
from llama_index.core.schema import TextNode

# Parent Docs
parent_docs = []

for i, page in enumerate(pdf.pages):
    parent_docs.append(
        TextNode(
            text=page.extract_text(),
            metadata = {
                'Author': meta.get('/Author', ''),
                'CreationDate': meta.get('/CreationDate', ''),
                'Creator': meta.get('/Creator', ''),
                'ModDate': meta.get('/ModDate', ''),
                'Title': meta.get('/Title', ''),
                'Page': pdf.pages.index(page) + 1
            }
        )
    )

# Child Docs
child_docs = []

for chunk in chunks:
    child_docs.append(
        TextNode(
            text=chunk['text'],
            metadata = {
                'ICD_Code': chunk['code'],
                'Page': chunk['page_number'],
                'Title': meta.get('/Title', '')
            }
        )
    )

# %%
from llama_index.core.schema import NodeRelationship, RelatedNodeInfo

for parent in parent_docs:
    for child in child_docs:
        if child.metadata['Page'] == parent.metadata['Page']:
            
            child.relationships[NodeRelationship.PARENT] = RelatedNodeInfo(
                node_id=parent.node_id
            )
            parent.relationships.setdefault(NodeRelationship.CHILD, [])
            parent.relationships[NodeRelationship.CHILD].append(
                RelatedNodeInfo(node_id=child.node_id)
            )

# %%
# Now you can use parent_docs and child_docs as needed
from llama_index.core import VectorStoreIndex, StorageContext, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# Initialize the embedding model
embeddings = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2", device="cuda")
Settings.embed_model = embeddings

storage_content = StorageContext.from_defaults()

all_nodes = parent_docs + child_docs

index = VectorStoreIndex.from_documents(
    embeddings=embeddings,
    documents=all_nodes,
    storage_context=storage_content,
    show_progress=True
)
# Out:
# Parsing nodes: 100%|██████████| 23443/23443 [00:05<00:00, 4274.08it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:04<00:00, 477.17it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 621.46it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 556.42it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 670.37it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 614.02it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 669.90it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 636.95it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:02<00:00, 685.01it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:02<00:00, 711.38it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 656.64it/s]
# Generating embeddings: 100%|██████████| 2048/2048 [00:03<00:00, 651.92it/s]
# Generating embeddings: 100%|██████████| 1030/1030 [00:01<00:00, 665.18it/s]

# %%
retriever = index.as_retriever(similarity_top_k=20)
result = retriever.retrieve("Welche ICD Codes für Diabetes mellitus gibt es?")
result
# Out:
# [NodeWithScore(node=TextNode(id_='c03eaf25-f912-4511-95f6-c16a8d207410', embedding=None, metadata={'ICD_Code': 'E07.9', 'Page': 138, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='8b22fc4e-fdfd-43f4-a970-132d3cd3f51c', node_type='1', metadata={'ICD_Code': 'E07.9', 'Page': 138, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='d60f1e19fecfa1f10234dfc71347e0338f5ae98d4bbec64080c74dfb9b725b49')}, metadata_template='{key}: {value}', metadata_separator='\n', text='E07.9 Krankheit der Schilddrüse, nicht näher bezeichnet\nDiabetes mellitus\n(', mimetype='text/plain', start_char_idx=0, end_char_idx=75, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7991898988268737),
#  NodeWithScore(node=TextNode(id_='81d3d549-9481-4232-88cf-4e8c36bbce9e', embedding=None, metadata={'ICD_Code': 'E14', 'Page': 141, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='38153d81-d99a-4bb3-b537-ba189b3e9cf1', node_type='1', metadata={'ICD_Code': 'E14', 'Page': 141, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='805bbeac15c085b9d3caa1969d1a53f13c168869682180c942be08e811d61177')}, metadata_template='{key}: {value}', metadata_separator='\n', text='E14.-  Nicht näher bezeichneter Diabetes mellitus\n[4. und 5. Stellen siehe am Anfang dieser Krankheitsgruppe]\nInkl.: Diabetes mellitus o.n.A.\nExkl.: Abnormer Glukosetoleranztest und sonstige Formen des Prädiabetes (', mimetype='text/plain', start_char_idx=0, end_char_idx=215, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7849973920241283),
#  NodeWithScore(node=TextNode(id_='b065d203-2dcf-4da2-ad44-05e031b983e0', embedding=None, metadata={'ICD_Code': 'E74', 'Page': 155, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1b34e36d-94ea-460d-bc13-ffeac95913b7', node_type='1', metadata={'ICD_Code': 'E74', 'Page': 155, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='14275bd823189747810e1afc81d96bbed440a470095fc33d069df847def03c8f')}, metadata_template='{key}: {value}', metadata_separator='\n', text='E74.-  Sonstige Störungen des Kohlenhydratstoffwechsels\nExkl.: Diabetes mellitus (', mimetype='text/plain', start_char_idx=0, end_char_idx=82, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7838965586524345),
#  NodeWithScore(node=TextNode(id_='36cb95e6-22b9-4a2b-852b-a040decda3b2', embedding=None, metadata={'ICD_Code': 'R73.08', 'Page': 140, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='99fb8935-42fb-42a3-8abc-ae45d99d89cd', node_type='1', metadata={'ICD_Code': 'R73.08', 'Page': 140, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='9a8d3309d002a2e59a16048b32f391d259f70970680f2ceb1029150715952612')}, metadata_template='{key}: {value}', metadata_separator='\n', text='R73.08)\nDiabetes mellitus:\n• beim Neugeborenen (', mimetype='text/plain', start_char_idx=0, end_char_idx=48, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7819475398780673),
#  NodeWithScore(node=TextNode(id_='844a7ae5-2ad9-44f0-9bea-ccb225b69f29', embedding=None, metadata={'ICD_Code': 'R73.08', 'Page': 139, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='45261c02-0d31-4ef3-b947-dfff58744b5e', node_type='1', metadata={'ICD_Code': 'R73.08', 'Page': 139, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='5521fc9bbe6b77e0f90fb93208232e5fc6dd9de7813f90f1ebb6fdd7ba1cf42b')}, metadata_template='{key}: {value}', metadata_separator='\n', text='R73.08)\nDiabetes mellitus:\n• beim Neugeborenen (', mimetype='text/plain', start_char_idx=0, end_char_idx=48, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.780171442478761),
#  NodeWithScore(node=TextNode(id_='646b4242-cf00-41d3-864d-052a8c2ff401', embedding=None, metadata={'ICD_Code': 'R73.08', 'Page': 141, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='514a6b41-de91-44dc-ace3-c06d533a3452', node_type='1', metadata={'ICD_Code': 'R73.08', 'Page': 141, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='0dd87940b7cc7e65740f40af7c995cb03e6be9ab045955c719a795e4d622ab79')}, metadata_template='{key}: {value}', metadata_separator='\n', text='R73.08)\nDiabetes mellitus:\n• beim Neugeborenen (', mimetype='text/plain', start_char_idx=0, end_char_idx=48, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7775100084252357),
#  NodeWithScore(node=TextNode(id_='40f5d804-73a4-4344-ba26-75e990dbf6dd', embedding=None, metadata={'ICD_Code': 'Z13.18', 'Page': 709, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='df449f7a-4d8e-4ac1-9c1d-fca56fbe873d', node_type='1', metadata={'ICD_Code': 'Z13.18', 'Page': 709, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='43d450a72781aa3301202b0e947de5f8d272b83465b03e1e5a02549e2332973c')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Z13.18 Sonstige spezielle Verfahren zur Untersuchung auf Diabetes mellitus', mimetype='text/plain', start_char_idx=0, end_char_idx=74, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.769329716199814),
#  NodeWithScore(node=TextNode(id_='969f7b2f-8e06-426d-8ea3-58c3fd2610d2', embedding=None, metadata={'ICD_Code': 'U69.75', 'Page': 757, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='63a7ce0a-3a44-45f5-a29d-8281074f4494', node_type='1', metadata={'ICD_Code': 'U69.75', 'Page': 757, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='11400ff48ffa2af9c164daa90f47442584b519625bd80c721c77ccbf2dc64e08')}, metadata_template='{key}: {value}', metadata_separator='\n', text='U69.75!, um bei Diabetes mellitus, Typ 1 (', mimetype='text/plain', start_char_idx=0, end_char_idx=42, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7651153837376302),
#  NodeWithScore(node=TextNode(id_='6c65186e-f720-42b1-8c68-49644455c719', embedding=None, metadata={'ICD_Code': 'E14', 'Page': 577, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='60bf18cb-f203-42d5-b82a-65f19ba4677f', node_type='1', metadata={'ICD_Code': 'E14', 'Page': 577, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='66848c97a4a19da9f8fda9af1876fa1c724016e0957fcc06a099684422fe92a6')}, metadata_template='{key}: {value}', metadata_separator='\n', text='E14)\nDiabetes mellitus während der Schwangerschaft, der Geburt und des Wochenbettes (', mimetype='text/plain', start_char_idx=0, end_char_idx=85, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7636150830128551),
#  NodeWithScore(node=TextNode(id_='3d70c756-7c89-4bd1-aa4d-37aac8597803', embedding=None, metadata={'ICD_Code': 'Z83.3', 'Page': 726, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b04188a5-d5f8-4ec7-befb-912edaed5962', node_type='1', metadata={'ICD_Code': 'Z83.3', 'Page': 726, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='f3be25e8bffd0d3c38343e0fe7586184506133c4803440f57fa777c85badac34')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Z83.3 Diabetes mellitus in der Familienanamnese\nZustände, klassifizierbar unter', mimetype='text/plain', start_char_idx=0, end_char_idx=79, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7596396062111488),
#  NodeWithScore(node=TextNode(id_='c0c79299-c23b-4f1d-9949-d5d64fd76193', embedding=None, metadata={'ICD_Code': 'Z13.1', 'Page': 709, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='3ca8c21a-052d-44ed-a148-fccd86ab3eb3', node_type='1', metadata={'ICD_Code': 'Z13.1', 'Page': 709, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='eb75706053e600cad45967c95b1e60b57bec89b1bc15e84d602e2226519f718a')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Z13.1- Spezielle Verfahren zur Untersuchung auf Diabetes mellitus', mimetype='text/plain', start_char_idx=0, end_char_idx=65, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7579951560880939),
#  NodeWithScore(node=TextNode(id_='ae8aa5b5-0055-4440-9e69-63039f857802', embedding=None, metadata={'ICD_Code': 'O24.9', 'Page': 477, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cb17320b-1321-47b9-8c3e-167d52838e20', node_type='1', metadata={'ICD_Code': 'O24.9', 'Page': 477, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='c7eb1d10b8575ee828dcb0f1b385ce2496d1005b6283b10469ec1fe9c25b8c93')}, metadata_template='{key}: {value}', metadata_separator='\n', text='O24.9 Diabetes mellitus in der Schwangerschaft, nicht näher bezeichnet', mimetype='text/plain', start_char_idx=0, end_char_idx=70, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7516125774004219),
#  NodeWithScore(node=TextNode(id_='cda8c32c-ea39-4fe4-aa7c-67341f8807f8', embedding=None, metadata={'ICD_Code': 'E14', 'Page': 135, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='68fc23d5-e0d5-4301-8396-7b00a6e09e7d', node_type='1', metadata={'ICD_Code': 'E14', 'Page': 135, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='67a7a6fd1c0a5b7c4f2b2b5e5f10be3e120b7adc9086cf570f760fe4112b11c3')}, metadata_template='{key}: {value}', metadata_separator='\n', text='E14 Diabetes mellitus', mimetype='text/plain', start_char_idx=0, end_char_idx=21, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7497460261892845),
#  NodeWithScore(node=TextNode(id_='f930477b-f93b-412d-8142-9dfa6fb5f86e', embedding=None, metadata={'ICD_Code': 'O24.3', 'Page': 476, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='430cda87-0fc4-4ecc-b9ad-a8683b708ab3', node_type='1', metadata={'ICD_Code': 'O24.3', 'Page': 476, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='2534e59f42309d65c8056aba2ca8af0f27702cdb7ca8f609b26cf785b5f2ea09')}, metadata_template='{key}: {value}', metadata_separator='\n', text='O24.3 Vorher bestehender Diabetes mellitus, nicht näher bezeichnet\nSystematisches Verzeichnis\n476', mimetype='text/plain', start_char_idx=0, end_char_idx=97, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7405330868994041),
#  NodeWithScore(node=TextNode(id_='4886a46a-f665-443d-822b-4dccd1f6ddb4', embedding=None, metadata={'ICD_Code': 'U69.73', 'Page': 757, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a42f77d7-f421-40c2-bcd0-98ef89ddc3ff', node_type='1', metadata={'ICD_Code': 'U69.73', 'Page': 757, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='b03699e2539cd72df1faf5d8790d0fb6f9a81291ca14cd002ddea4485d5776b1')}, metadata_template='{key}: {value}', metadata_separator='\n', text='U69.73! Hypoglykämisches Koma bei Diabetes mellitus\nICD-10-GM Version 2026\n757', mimetype='text/plain', start_char_idx=0, end_char_idx=78, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7402481207137134),
#  NodeWithScore(node=TextNode(id_='ebb574c4-436b-4506-ba99-e8c28cd9c32e', embedding=None, metadata={'ICD_Code': 'O24.1', 'Page': 476, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e5ae1036-6f9c-447c-af1d-87ef902a4438', node_type='1', metadata={'ICD_Code': 'O24.1', 'Page': 476, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='1083094fc7e87f46c091d5fdd16622ab50f0156d5c3f12a9da77fb539f158132')}, metadata_template='{key}: {value}', metadata_separator='\n', text='O24.1 Vorher bestehender Diabetes mellitus, Typ 2', mimetype='text/plain', start_char_idx=0, end_char_idx=49, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.735123481937113),
#  NodeWithScore(node=TextNode(id_='a657460d-b3bd-4da6-81c6-859c827031a6', embedding=None, metadata={'ICD_Code': 'I79.2', 'Page': 139, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a42788f4-e618-420b-8d94-81f6c7116057', node_type='1', metadata={'ICD_Code': 'I79.2', 'Page': 139, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='20a0696bcae869c7d4a5ceff83f8095d48406e993ce40fca1ddea86e8ccdfc64')}, metadata_template='{key}: {value}', metadata_separator='\n', text='I79.2*)\n• Ulkus\n.6 Mit sonstigen näher bezeichneten Komplikationen\nDiabetische Arthropathie† (', mimetype='text/plain', start_char_idx=0, end_char_idx=94, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7350581348800258),
#  NodeWithScore(node=TextNode(id_='aa3d2e15-759e-43e7-bbb2-150a923750d1', embedding=None, metadata={'ICD_Code': 'O24', 'Page': 476, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1747544d-45c1-4880-8768-224ce27c1c8e', node_type='1', metadata={'ICD_Code': 'O24', 'Page': 476, 'Title': 'ICD-10-GM Version 2026 Systematisches Verzeichnis - Referenzfassung'}, hash='c6da50b90091c426e2ca77dc98b100050e01bca8020a93858126023750b9045d')}, metadata_template='{key}: {value}', metadata_separator='\n', text='O24.-  Diabetes mellitus in der Schwangerschaft\nInkl.: Bei Geburt und im Wochenbett', mimetype='text/plain', start_char_idx=0, end_char_idx=83, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.7336842844793068)]

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

model = ChatOllama(model="qwen3:4b", temperature=0.1)

# %%
context = "\n\n".join([doc.text for doc in result])

prompt = PromptTemplate.from_template(
    "Basierend auf dem folgenden Kontext beantworte die Frage präzise:\n\n"
    "Lasse keine Informationen weg und erfinde keine Antworten.\n\n"
    "Kontext:\n{context}\n\n"
    "Frage: {question}\n\n"
    "Antwort:"
)

qa = prompt | model | StrOutputParser()

qa_result = qa.invoke({'context': context, 'question': "Welche ICD Codes für Diabetes mellitus gibt es?"})
qa_result
# Out:
# 'Basierend auf der gegebenen Information und den ICD-10-Klassifikationen für Diabetes mellitus, sind die folgenden ICD-Codes spezifisch für Diabetes mellitus selbst (d.h. die Krankheit, nicht Komplikationen oder Prozeduren):\n\n1. **E14.-** – Unspezifiziertes Diabetes mellitus (allgemeiner Code für Diabetes mellitus ohne weitere Spezifikation)  \n2. **O24.9** – Diabetes mellitus in der Schwangerschaft, unspezifiziert  \n3. **O24.3** – Vorhergegangenes Diabetes mellitus, unspezifiziert  \n4. **O24.1** – Vorhergegangenes Diabetes mellitus, Typ 2  \n5. **R73.08** – Diabetes mellitus bei Neugeborenen  \n\n### Begründung:\n- **E14.-** ist der Code für Diabetes mellitus ohne weitere Spezifikation (z.B. Typ 1/2 oder Schwangerschaft).  \n- **O24.9**, **O24.3** und **O24.1** sind spezifische Codes für Diabetes mellitus in der Schwangerschaft oder bei Vorhergegangenem Diabetes (inkl. Typ 2).  \n- **R73.08** bezieht sich auf Diabetes mellitus bei Neugeborenen (eine spezifische Situation).  \n- Andere Codes wie **U69.75** (Diabetes mellitus, Typ 1 in der Schwangerschaft) sind **nicht** für die Krankheit selbst, sondern für Komplikationen der Schwangerschaft (U69 ist die Kategorie für "Komplikationen der Schwangerschaft").  \n- **Z83.3** (Diabetes mellitus in der Familienanamnese) und **Z13.18** (Prozeduren zur Diagnose) sind nicht Krankheitscodes, sondern Anamnese- oder Prozedurcodes.  \n\nDiese fünf Codes sind die **eindeutig für Diabetes mellitus selbst** definierten ICD-10-Codes, wie sie im gegebenen Kontext beschrieben werden.  \n\n**Antwort:** E14.-, O24.9, O24.3, O24.1, R73.08'

# %%
from IPython.display import display, Markdown

display(Markdown(f"**Antwort:** {qa_result}"))
# Out:
# **Antwort:** Basierend auf der gegebenen Information und den ICD-10-Klassifikationen für Diabetes mellitus, sind die folgenden ICD-Codes spezifisch für Diabetes mellitus selbst (d.h. die Krankheit, nicht Komplikationen oder Prozeduren):
#
# 1. **E14.-** – Unspezifiziertes Diabetes mellitus (allgemeiner Code für Diabetes mellitus ohne weitere Spezifikation)
# 2. **O24.9** – Diabetes mellitus in der Schwangerschaft, unspezifiziert
# 3. **O24.3** – Vorhergegangenes Diabetes mellitus, unspezifiziert
# 4. **O24.1** – Vorhergegangenes Diabetes mellitus, Typ 2
# 5. **R73.08** – Diabetes mellitus bei Neugeborenen
#
# ### Begründung:
# - **E14.-** ist der Code für Diabetes mellitus ohne weitere Spezifikation (z.B. Typ 1/2 oder Schwangerschaft).
# - **O24.9**, **O24.3** und **O24.1** sind spezifische Codes für Diabetes mellitus in der Schwangerschaft oder bei Vorhergegangenem Diabetes (inkl. Typ 2).
# - **R73.08** bezieht sich auf Diabetes mellitus bei Neugeborenen (eine spezifische Situation).
# - Andere Codes wie **U69.75** (Diabetes mellitus, Typ 1 in der Schwangerschaft) sind **nicht** für die Krankheit selbst, sondern für Komplikationen der Schwangerschaft (U69 ist die Kategorie für "Komplikationen der Schwangerschaft").
# - **Z83.3** (Diabetes mellitus in der Familienanamnese) und **Z13.18** (Prozeduren zur Diagnose) sind nicht Krankheitscodes, sondern Anamnese- oder Prozedurcodes.
#
# Diese fünf Codes sind die **eindeutig für Diabetes mellitus selbst** definierten ICD-10-Codes, wie sie im gegebenen Kontext beschrieben werden.
#
# **Antwort:** E14.-, O24.9, O24.3, O24.1, R73.08
